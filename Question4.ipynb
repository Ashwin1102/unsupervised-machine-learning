# %%
import ast
import networkx as nx

# %%
G = nx.MultiDiGraph()

with open('graph.txt', 'r') as f:
    for line in f:
        edge = ast.literal_eval(line.strip())
        G.add_edge(edge[0], edge[2], label=edge[1])

# %%
annotations = []

with open('annotations.txt', 'r') as f:
    for line in f:
        annot = ast.literal_eval(line.strip())
        annotations.append(annot)

# %%
from gensim import models
from nltk import word_tokenize
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import json

# Helper code
word2vec_model = models.Word2Vec.load('word2vec_train_dev.dat')

def get_rel_score_word2vecbase(rel: str, query: str) -> float:
    if rel not in word2vec_model.wv:
        return 0.0

    rel = 'ns:' + rel if not rel[:3] == 'ns:' else rel

    words = word_tokenize(query.lower())
    w_embs = []
    for w in words:
        if w in word2vec_model.wv:
            w_embs.append(word2vec_model.wv[w])
    return np.mean(cosine_similarity(w_embs, [word2vec_model.wv[rel]]))

# %%
import heapq

def get_answers(annotations, iters=100, topk=10):
    final_answers = []
    for i in tqdm(range(len(annotations)), desc="Processing annotations"):
        n = iters
        query = annotations[i][1]
        start_node = annotations[i][2]
        start_rel = annotations[i][3][0][1]

        queue = [(1, start_node, start_rel)]  # Use score as first element for heap
        visited = set()
        answer_candidates = []

        while queue and n > 0:
            score, curr_node, curr_rel = heapq.heappop(queue)
            score = -score  # Because heapq is min-heap

            if (curr_node, curr_rel) in visited:
                continue
            visited.add((curr_node, curr_rel))

            for _, target, edge in G.out_edges(curr_node, data=True):
                rel = edge['label']
                full_rel = 'ns:' + rel if not rel.startswith('ns:') else rel
                new_score = get_rel_score_word2vecbase(full_rel, query)
                if (target, full_rel) not in visited:
                    heapq.heappush(queue, (-new_score, target, full_rel))
                    answer_candidates.append((target, new_score))

            n -= 1

        best_nodes = sorted(answer_candidates, key=lambda x: -x[1])[:topk]
        final_answers.append([node for node, _ in best_nodes])
    return final_answers

# %%
final_answers = get_answers(annotations, 100)
# Out:
# Processing annotations: 100%|██████████████████████████████████████████████████████████| 56/56 [01:06<00:00,  1.19s/it]

# %%
def compute_f1(pred, actual_data):
    answers = {ans['AnswerArgument'] for ans in actual_data[-1]}
    s = set(pred)

    tp = len(answers & s)
    p = tp / len(s) if s else 0.0
    r = tp / len(answers) if answers else 0.0

    if p + r == 0:
        return 0.0
    f1 = 2 * p * r / (p + r)
    return f1

# %%
f1s = []
for i in range(len(annotations)):
    f1s.append(compute_f1(final_answers[i], annotations[i]))

sum(f1s) / len(f1s)
# Out:
# 0.3172535862170956
