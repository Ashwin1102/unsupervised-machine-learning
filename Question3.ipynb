# %%
import pandas as pd

df = pd.read_csv("comm.txt", header=None, names=["source", "target", "1"])

# %%
df.drop('1', axis=1, inplace=True)

# %%
G = nx.Graph()
for _, row in df.iterrows():
    G.add_edge(row["source"], row["target"])

# %%
A = nx.to_numpy_array(G)
degrees = A.sum(axis=1)
m = A.sum() / 2
B = A - np.outer(degrees, degrees) / (2 * m)

# %%
vals, vecs = eigsh(B, k=1, which='LA')
v1 = vecs[:, 0]
s = np.sign(v1)
nodes = list(G.nodes())

community_1 = [nodes[i] for i in range(len(nodes)) if s[i] >= 0]
community_2 = [nodes[i] for i in range(len(nodes)) if s[i] < 0]

# %%
labels = []
for node in G.nodes():
    if node in community_1:
        labels.append('blue') 
    elif node in community_2:
        labels.append('green')
    else:
        labels.append('gray')

# %%
nx.draw(G, node_color=labels, edge_color='gray', node_size=10, font_size=10)
plt.show()
