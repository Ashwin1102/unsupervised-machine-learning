# %%
import pandas as pd

# %%
df = pd.read_csv('20ng.csv')
df['index'] = df['index'].str.replace(r'\d+$', '', regex=True)
classes = ["alt.atheism", "sci.med", "sci.electronics", "comp.graphics", "talk.politics.guns", "sci.crypt"]
df = df[df['index'].isin(classes)]

# %%
stopwords = [
 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're",
 "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he',
 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's",
 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which',
 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are',
 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do',
 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because',
 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against',
 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below',
 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again',
 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all',
 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no',
 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't',
 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll',
 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't",
 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't",
 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn',
 "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't",
 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'would'
]

# %%
text = df.iloc[0, 1]

# %%
text
# Out:
# 'Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:49960 alt.atheism.moderated:713 news.answers:7054 alt.answers:126\nPath: cantaloupe.srv.cs.cmu.edu!crabapple.srv.cs.cmu.edu!bb3.andrew.cmu.edu!news.sei.cmu.edu!cis.ohio-state.edu!magnus.acs.ohio-state.edu!usenet.ins.cwru.edu!agate!spool.mu.edu!uunet!pipex!ibmpcug!mantis!mathew\nFrom: mathew <mathew@mantis.co.uk>\nNewsgroups: alt.atheism,alt.atheism.moderated,news.answers,alt.answers\nSubject: Alt.Atheism FAQ: Atheist Resources\nSummary: Books, addresses, music -- anything related to atheism\nKeywords: FAQ, atheism, books, music, fiction, addresses, contacts\nMessage-ID: <19930329115719@mantis.co.uk>\nDate: Mon, 29 Mar 1993 11:57:19 GMT\nExpires: Thu, 29 Apr 1993 11:57:19 GMT\nFollowup-To: alt.atheism\nDistribution: world\nOrganization: Mantis Consultants, Cambridge. UK.\nApproved: news-answers-request@mit.edu\nSupersedes: <19930301143317@mantis.co.uk>\nLines: 290\n\nArchive-name: atheism/resources\nAlt-atheism-archive-name: resources\nLast
# ...

# %%
import numpy as np

vocab_dict = {}
counter = 0
D = 6000

for i in range(6000):
    
    text = df.iloc[i, 1]
    # text = text[-1000:]
    curr_words = text.split(' ')[-1000:]

    for w in curr_words:
        if w not in vocab_dict and w not in stopwords:
            vocab_dict[w] = counter
            counter += 1

max_words = len(vocab_dict)
docs = -1 * np.ones((D, max_words), dtype=int)

for i in range(6000):
    text = df.iloc[i, 1]
    # text = text[-1000:]
    curr_words = text.split(' ')[-1000:]

    for w in range(len(curr_words)):
        if curr_words[w] in vocab_dict:
            docs[i, w] = vocab_dict[curr_words[w]]

# %%
import numpy as np
K = 6
W = docs.shape[1]
a = 5 * np.ones((1,K))
b = 2 * np.ones((1, W))

# %%
z = np.zeros((D, W), dtype=int)

# %%
A = np.zeros((D, K))
A[:] = a

B = np.zeros((K, W))
B[:] = b

# %%
bsum = np.sum(B, axis=1)

# %%
W
# Out:
# 231787

# %%
A.shape
# Out:
# (6000, 6)

# %%
B.shape
# Out:
# (6, 231787)

# %%
from tqdm import trange

for t in trange(1000):
    for d in range(D):
        for i in range(W):
            w = docs[d, i]

            if w == -1:
                break
                
            zi = z[d, i]

            if zi>0:
                A[d, zi] -= 1 
                B[zi, w] -= 1
                bsum[zi] -= 1
            
            dst = A[d, :] * (B[:, w]/bsum)
            dst = dst / dst.sum()
            new_zi = np.random.choice(np.arange(K), p=dst)
            z[d, i] = new_zi
            A[d, new_zi] += 1
            B[new_zi, w] += 1
            bsum[new_zi] += 1
# Out:
# 100%|██████████| 1000/1000 [48:00<00:00,  2.88s/it]

# %%
def build_cloud(k):
    from wordcloud import WordCloud
    import matplotlib.pyplot as plt
    d = {}

    for word in vocab_dict:
        if B[0, vocab_dict[word]] > 0:
            d[word] = int(B[k, vocab_dict[word]])
    
    d1 = {}

    for key in d:
        if key.isalpha() and len(key)>2 and key.lower() not in stopwords:
            d1[key] = d[key]
    top_n = 100
    top_items = dict(sorted(d1.items(), key=lambda item: item[1], reverse=True)[:top_n])
    wc = WordCloud(background_color="white")
    wc.generate_from_frequencies(top_items)
    
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
build_cloud(0)

# %%
build_cloud(1)

# %%
build_cloud(2)

# %%
build_cloud(3)

# %%
build_cloud(4)

# %%
build_cloud(5)

# %%
top_n = 20
top_items = dict(sorted(d1.items(), key=lambda item: item[1], reverse=True)[:top_n])

wc = WordCloud(background_color="white")

# %%
top_items
# Out:
# {'rrender': 72507,
#  'peak': 64654,
#  'ensure': 41734,
#  'opinions': 35847,
#  'like': 32864,
#  'PGP': 31836,
#  'Research': 30886,
#  'lay': 28861,
#  'one': 26854,
#  'lui': 24926,
#  'laissez': 24904,
#  'monde': 24884,
#  'University': 23887,
#  'Private': 22930,
#  'amateur': 22921,
#  'radio': 22921,
#  'Box': 22903,
#  'Manhattan': 22899,
#  'sank': 22893,
#  'activities': 21950}

# %%
wc = WordCloud(background_color="white")

# %%
wc.generate_from_frequencies(top_items)

# %%
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()
